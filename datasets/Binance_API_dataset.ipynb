# %%
from google.colab import drive
import numpy as np
import pandas as pd
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
# Imports and classes from https://bablofil.ru/binance-api/

import time
import json
import urllib
import hmac, hashlib
import requests

from urllib.parse import urlparse, urlencode
from urllib.request import Request, urlopen

class Binance():

    methods = {
            # public methods
            'ping':             {'url':'api/v1/ping', 'method': 'GET', 'private': False},
            'time':             {'url':'api/v1/time', 'method': 'GET', 'private': False},
            'exchangeInfo':     {'url':'api/v1/exchangeInfo', 'method': 'GET', 'private': False},
            'depth':            {'url': 'api/v1/depth', 'method': 'GET', 'private': False},
            'trades':           {'url': 'api/v1/trades', 'method': 'GET', 'private': False},
            'historicalTrades': {'url': 'api/v1/historicalTrades', 'method': 'GET', 'private': False},
            'aggTrades':        {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False},
            'klines':           {'url': 'api/v1/klines', 'method': 'GET', 'private': False},
            'ticker24hr':       {'url': 'api/v1/ticker/24hr', 'method': 'GET', 'private': False},
            'tickerPrice':      {'url': 'api/v3/ticker/price', 'method': 'GET', 'private': False},
            'tickerBookTicker': {'url': 'api/v3/ticker/bookTicker', 'method': 'GET', 'private': False},
            # private methods
            'createOrder':      {'url': 'api/v3/order', 'method': 'POST', 'private': True},
            'testOrder':        {'url': 'api/v3/order/test', 'method': 'POST', 'private': True},
            'orderInfo':        {'url': 'api/v3/order', 'method': 'GET', 'private': True},
            'cancelOrder':      {'url': 'api/v3/order', 'method': 'DELETE', 'private': True},
            'openOrders':       {'url': 'api/v3/openOrders', 'method': 'GET', 'private': True},
            'allOrders':        {'url': 'api/v3/allOrders', 'method': 'GET', 'private': True},
            'account':          {'url': 'api/v3/account', 'method': 'GET', 'private': True},
            'myTrades':         {'url': 'api/v3/myTrades', 'method': 'GET', 'private': True},
            # wapi
            'depositAddress':   {'url': 'wapi/v3/depositAddress.html', 'method':'GET', 'private':True},
            'withdraw':   {'url': 'wapi/v3/withdraw.html', 'method':'POST', 'private':True},
            'depositHistory': {'url': 'wapi/v3/depositHistory.html', 'method':'GET', 'private':True},
            'withdrawHistory': {'url': 'wapi/v3/withdrawHistory.html', 'method':'GET', 'private':True},
            'assetDetail': {'url': 'wapi/v3/assetDetail.html', 'method':'GET', 'private':True},
            'tradeFee': {'url': 'wapi/v3/tradeFee.html', 'method':'GET', 'private':True},
            'accountStatus': {'url': 'wapi/v3/accountStatus.html', 'method':'GET', 'private':True},
            'systemStatus': {'url': 'wapi/v3/systemStatus.html', 'method':'GET', 'private':True},
            'assetDust': {'url': 'sapi/v1/asset/dust', 'method':'POST', 'private':True},
            'dustLog': {'url': 'wapi/v3/userAssetDribbletLog.html', 'method':'GET', 'private':True},
            'assetAssetDividend': {'url': 'sapi/v1/asset/assetDividend', 'method':'GET', 'private':True},
            #sapi
            'marginTransfer': {'url': 'sapi/v1/margin/transfer', 'method': 'POST', 'private':True},
            'marginLoan': {'url': 'sapi/v1/margin/loan', 'method': 'POST', 'private':True},
            'marginRepay': {'url': 'sapi/v1/margin/repay', 'method': 'POST', 'private':True},
            'marginCreateOrder': {'url': 'sapi/v1/margin/order', 'method': 'POST', 'private':True},
            'marginCancelOrder': {'url': 'sapi/v1/margin/order', 'method': 'DELETE', 'private':True},
            'marginOrderInfo': {'url': 'sapi/v1/margin/order', 'method': 'GET', 'private':True},
            'marginAccount': {'url': 'sapi/v1/margin/account', 'method': 'POST', 'private':True},
            'marginOpenOrders': {'url': 'sapi/v1/margin/openOrders', 'method': 'GET', 'private':True},
            'marginAllOrders': {'url': 'sapi/v1/margin/allOrders', 'method': 'GET', 'private':True},
            'marginAsset': {'url': 'sapi/v1/margin/asset', 'method': 'POST', 'private':True},
            'marginPair': {'url': 'sapi/v1/margin/pair', 'method': 'POST', 'private':True},
            'marginPriceIndex': {'url': 'sapi/v1/margin/priceIndex', 'method': 'POST', 'private':True},
            'marginMyTrades': {'url': 'sapi/v1/margin/myTrades', 'method': 'GET', 'private':True},
            'marginMaxBorrowable': {'url': 'sapi/v1/margin/maxBorrowable', 'method': 'GET', 'private':True},
            'marginmaxTransferable': {'url': 'sapi/v1/margin/maxTransferable', 'method': 'GET', 'private':True},            
   }
    
    def __init__(self, API_KEY, API_SECRET):
        self.API_KEY = API_KEY
        self.API_SECRET = bytearray(API_SECRET, encoding='utf-8')
        self.shift_seconds = 0

    def __getattr__(self, name):
        def wrapper(*args, **kwargs):
            kwargs.update(command=name)
            return self.call_api(**kwargs)
        return wrapper

    def set_shift_seconds(self, seconds):
        self.shift_seconds = seconds
        
    def call_api(self, **kwargs):

        command = kwargs.pop('command')
        api_url = 'https://api.binance.com/' + self.methods[command]['url']

        payload = kwargs
        headers = {}
        
        payload_str = urllib.parse.urlencode(payload)
        if self.methods[command]['private']:
            payload.update({'timestamp': int(time.time() + self.shift_seconds - 1) * 1000})
            payload_str = urllib.parse.urlencode(payload).encode('utf-8')
            sign = hmac.new(
                key=self.API_SECRET,
                msg=payload_str,
                digestmod=hashlib.sha256
            ).hexdigest()

            payload_str = payload_str.decode("utf-8") + "&signature="+str(sign) 
            headers = {"X-MBX-APIKEY": self.API_KEY}

        if self.methods[command]['method'] == 'GET' or self.methods[command]['url'].startswith('sapi'):
            api_url += '?' + payload_str

        print(api_url, payload_str, self.methods[command])
        response = requests.request(method=self.methods[command]['method'], url=api_url, data="" if self.methods[command]['method'] == 'GET' else payload_str, headers=headers)

            
        if 'code' in response.text:
            print(response.text)
        return response.json()

# %%
# Bot for downloading the history
bot = Binance(
    API_KEY='D7...Ejj',
    API_SECRET='gwQ...u3A'
)

# %%
# Setting the starting point of dataset
start = 1551225600000
for i in range(12,13):
  day_start = i * 30
  day_end = day_start + 5
  # Root where to save files
  title = r"/content/drive/My Drive/"+str(i)+".csv"
  history = []
  for i in range(24*day_start + 1, 24*day_end + 1):
    # Symbol - the pair of currencies, difference between start and end - no more than 1 hour
    history += [bot.aggTrades(symbol='ETHUSDT', startTime = start+(i-1)*60000*60, endTime = start+i*60000*60)]
    print(i,'/8760')
  history_list = []
  for i in history:
    for j in i:
      # Setting the column names
      history_list += [[j['M'],j['T'],j['a'],j['f'], j['l'], j['m'], j['p'], j['q']]]
  data = pd.DataFrame(history_list, columns= ['M', 'T', 'a', 'f', 'l', 'm', 'p', 'q'])
  data.to_csv(title)
# Out:
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582329600000&endTime=1582333200000 symbol=ETHUSDT&startTime=1582329600000&endTime=1582333200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8641 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582333200000&endTime=1582336800000 symbol=ETHUSDT&startTime=1582333200000&endTime=1582336800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8642 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582336800000&endTime=1582340400000 symbol=ETHUSDT&startTime=1582336800000&endTime=1582340400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8643 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582340400000&endTime=1582344000000 symbol=ETHUSDT&startTime=1582340400000&endTime=1582344000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8644 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582344000000&endTime=1582347600000 symbol=ETHUSDT&startTime=1582344000000&endTime=1582347600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8645 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582347600000&endTime=1582351200000 symbol=ETHUSDT&startTime=1582347600000&endTime=1582351200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8646 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582351200000&endTime=1582354800000 symbol=ETHUSDT&startTime=1582351200000&endTime=1582354800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8647 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582354800000&endTime=1582358400000 symbol=ETHUSDT&startTime=1582354800000&endTime=1582358400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8648 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582358400000&endTime=1582362000000 symbol=ETHUSDT&startTime=1582358400000&endTime=1582362000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8649 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582362000000&endTime=1582365600000 symbol=ETHUSDT&startTime=1582362000000&endTime=1582365600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8650 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582365600000&endTime=1582369200000 symbol=ETHUSDT&startTime=1582365600000&endTime=1582369200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8651 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582369200000&endTime=1582372800000 symbol=ETHUSDT&startTime=1582369200000&endTime=1582372800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8652 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582372800000&endTime=1582376400000 symbol=ETHUSDT&startTime=1582372800000&endTime=1582376400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8653 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582376400000&endTime=1582380000000 symbol=ETHUSDT&startTime=1582376400000&endTime=1582380000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8654 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582380000000&endTime=1582383600000 symbol=ETHUSDT&startTime=1582380000000&endTime=1582383600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8655 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582383600000&endTime=1582387200000 symbol=ETHUSDT&startTime=1582383600000&endTime=1582387200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8656 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582387200000&endTime=1582390800000 symbol=ETHUSDT&startTime=1582387200000&endTime=1582390800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8657 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582390800000&endTime=1582394400000 symbol=ETHUSDT&startTime=1582390800000&endTime=1582394400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8658 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582394400000&endTime=1582398000000 symbol=ETHUSDT&startTime=1582394400000&endTime=1582398000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8659 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582398000000&endTime=1582401600000 symbol=ETHUSDT&startTime=1582398000000&endTime=1582401600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8660 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582401600000&endTime=1582405200000 symbol=ETHUSDT&startTime=1582401600000&endTime=1582405200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8661 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582405200000&endTime=1582408800000 symbol=ETHUSDT&startTime=1582405200000&endTime=1582408800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8662 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582408800000&endTime=1582412400000 symbol=ETHUSDT&startTime=1582408800000&endTime=1582412400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8663 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582412400000&endTime=1582416000000 symbol=ETHUSDT&startTime=1582412400000&endTime=1582416000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8664 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582416000000&endTime=1582419600000 symbol=ETHUSDT&startTime=1582416000000&endTime=1582419600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8665 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582419600000&endTime=1582423200000 symbol=ETHUSDT&startTime=1582419600000&endTime=1582423200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8666 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582423200000&endTime=1582426800000 symbol=ETHUSDT&startTime=1582423200000&endTime=1582426800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8667 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582426800000&endTime=1582430400000 symbol=ETHUSDT&startTime=1582426800000&endTime=1582430400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8668 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582430400000&endTime=1582434000000 symbol=ETHUSDT&startTime=1582430400000&endTime=1582434000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8669 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582434000000&endTime=1582437600000 symbol=ETHUSDT&startTime=1582434000000&endTime=1582437600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8670 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582437600000&endTime=1582441200000 symbol=ETHUSDT&startTime=1582437600000&endTime=1582441200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8671 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582441200000&endTime=1582444800000 symbol=ETHUSDT&startTime=1582441200000&endTime=1582444800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8672 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582444800000&endTime=1582448400000 symbol=ETHUSDT&startTime=1582444800000&endTime=1582448400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8673 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582448400000&endTime=1582452000000 symbol=ETHUSDT&startTime=1582448400000&endTime=1582452000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8674 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582452000000&endTime=1582455600000 symbol=ETHUSDT&startTime=1582452000000&endTime=1582455600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8675 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582455600000&endTime=1582459200000 symbol=ETHUSDT&startTime=1582455600000&endTime=1582459200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8676 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582459200000&endTime=1582462800000 symbol=ETHUSDT&startTime=1582459200000&endTime=1582462800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8677 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582462800000&endTime=1582466400000 symbol=ETHUSDT&startTime=1582462800000&endTime=1582466400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8678 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582466400000&endTime=1582470000000 symbol=ETHUSDT&startTime=1582466400000&endTime=1582470000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8679 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582470000000&endTime=1582473600000 symbol=ETHUSDT&startTime=1582470000000&endTime=1582473600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8680 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582473600000&endTime=1582477200000 symbol=ETHUSDT&startTime=1582473600000&endTime=1582477200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8681 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582477200000&endTime=1582480800000 symbol=ETHUSDT&startTime=1582477200000&endTime=1582480800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8682 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582480800000&endTime=1582484400000 symbol=ETHUSDT&startTime=1582480800000&endTime=1582484400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8683 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582484400000&endTime=1582488000000 symbol=ETHUSDT&startTime=1582484400000&endTime=1582488000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8684 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582488000000&endTime=1582491600000 symbol=ETHUSDT&startTime=1582488000000&endTime=1582491600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8685 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582491600000&endTime=1582495200000 symbol=ETHUSDT&startTime=1582491600000&endTime=1582495200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8686 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582495200000&endTime=1582498800000 symbol=ETHUSDT&startTime=1582495200000&endTime=1582498800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8687 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582498800000&endTime=1582502400000 symbol=ETHUSDT&startTime=1582498800000&endTime=1582502400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8688 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582502400000&endTime=1582506000000 symbol=ETHUSDT&startTime=1582502400000&endTime=1582506000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8689 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582506000000&endTime=1582509600000 symbol=ETHUSDT&startTime=1582506000000&endTime=1582509600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8690 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582509600000&endTime=1582513200000 symbol=ETHUSDT&startTime=1582509600000&endTime=1582513200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8691 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582513200000&endTime=1582516800000 symbol=ETHUSDT&startTime=1582513200000&endTime=1582516800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8692 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582516800000&endTime=1582520400000 symbol=ETHUSDT&startTime=1582516800000&endTime=1582520400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8693 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582520400000&endTime=1582524000000 symbol=ETHUSDT&startTime=1582520400000&endTime=1582524000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8694 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582524000000&endTime=1582527600000 symbol=ETHUSDT&startTime=1582524000000&endTime=1582527600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8695 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582527600000&endTime=1582531200000 symbol=ETHUSDT&startTime=1582527600000&endTime=1582531200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8696 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582531200000&endTime=1582534800000 symbol=ETHUSDT&startTime=1582531200000&endTime=1582534800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8697 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582534800000&endTime=1582538400000 symbol=ETHUSDT&startTime=1582534800000&endTime=1582538400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8698 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582538400000&endTime=1582542000000 symbol=ETHUSDT&startTime=1582538400000&endTime=1582542000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8699 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582542000000&endTime=1582545600000 symbol=ETHUSDT&startTime=1582542000000&endTime=1582545600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8700 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582545600000&endTime=1582549200000 symbol=ETHUSDT&startTime=1582545600000&endTime=1582549200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8701 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582549200000&endTime=1582552800000 symbol=ETHUSDT&startTime=1582549200000&endTime=1582552800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8702 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582552800000&endTime=1582556400000 symbol=ETHUSDT&startTime=1582552800000&endTime=1582556400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8703 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582556400000&endTime=1582560000000 symbol=ETHUSDT&startTime=1582556400000&endTime=1582560000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8704 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582560000000&endTime=1582563600000 symbol=ETHUSDT&startTime=1582560000000&endTime=1582563600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8705 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582563600000&endTime=1582567200000 symbol=ETHUSDT&startTime=1582563600000&endTime=1582567200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8706 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582567200000&endTime=1582570800000 symbol=ETHUSDT&startTime=1582567200000&endTime=1582570800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8707 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582570800000&endTime=1582574400000 symbol=ETHUSDT&startTime=1582570800000&endTime=1582574400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8708 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582574400000&endTime=1582578000000 symbol=ETHUSDT&startTime=1582574400000&endTime=1582578000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8709 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582578000000&endTime=1582581600000 symbol=ETHUSDT&startTime=1582578000000&endTime=1582581600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8710 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582581600000&endTime=1582585200000 symbol=ETHUSDT&startTime=1582581600000&endTime=1582585200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8711 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582585200000&endTime=1582588800000 symbol=ETHUSDT&startTime=1582585200000&endTime=1582588800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8712 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582588800000&endTime=1582592400000 symbol=ETHUSDT&startTime=1582588800000&endTime=1582592400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8713 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582592400000&endTime=1582596000000 symbol=ETHUSDT&startTime=1582592400000&endTime=1582596000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8714 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582596000000&endTime=1582599600000 symbol=ETHUSDT&startTime=1582596000000&endTime=1582599600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8715 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582599600000&endTime=1582603200000 symbol=ETHUSDT&startTime=1582599600000&endTime=1582603200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8716 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582603200000&endTime=1582606800000 symbol=ETHUSDT&startTime=1582603200000&endTime=1582606800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8717 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582606800000&endTime=1582610400000 symbol=ETHUSDT&startTime=1582606800000&endTime=1582610400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8718 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582610400000&endTime=1582614000000 symbol=ETHUSDT&startTime=1582610400000&endTime=1582614000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8719 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582614000000&endTime=1582617600000 symbol=ETHUSDT&startTime=1582614000000&endTime=1582617600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8720 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582617600000&endTime=1582621200000 symbol=ETHUSDT&startTime=1582617600000&endTime=1582621200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8721 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582621200000&endTime=1582624800000 symbol=ETHUSDT&startTime=1582621200000&endTime=1582624800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8722 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582624800000&endTime=1582628400000 symbol=ETHUSDT&startTime=1582624800000&endTime=1582628400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8723 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582628400000&endTime=1582632000000 symbol=ETHUSDT&startTime=1582628400000&endTime=1582632000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8724 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582632000000&endTime=1582635600000 symbol=ETHUSDT&startTime=1582632000000&endTime=1582635600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8725 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582635600000&endTime=1582639200000 symbol=ETHUSDT&startTime=1582635600000&endTime=1582639200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8726 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582639200000&endTime=1582642800000 symbol=ETHUSDT&startTime=1582639200000&endTime=1582642800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8727 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582642800000&endTime=1582646400000 symbol=ETHUSDT&startTime=1582642800000&endTime=1582646400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8728 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582646400000&endTime=1582650000000 symbol=ETHUSDT&startTime=1582646400000&endTime=1582650000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8729 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582650000000&endTime=1582653600000 symbol=ETHUSDT&startTime=1582650000000&endTime=1582653600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8730 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582653600000&endTime=1582657200000 symbol=ETHUSDT&startTime=1582653600000&endTime=1582657200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8731 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582657200000&endTime=1582660800000 symbol=ETHUSDT&startTime=1582657200000&endTime=1582660800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8732 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582660800000&endTime=1582664400000 symbol=ETHUSDT&startTime=1582660800000&endTime=1582664400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8733 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582664400000&endTime=1582668000000 symbol=ETHUSDT&startTime=1582664400000&endTime=1582668000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8734 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582668000000&endTime=1582671600000 symbol=ETHUSDT&startTime=1582668000000&endTime=1582671600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8735 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582671600000&endTime=1582675200000 symbol=ETHUSDT&startTime=1582671600000&endTime=1582675200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8736 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582675200000&endTime=1582678800000 symbol=ETHUSDT&startTime=1582675200000&endTime=1582678800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8737 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582678800000&endTime=1582682400000 symbol=ETHUSDT&startTime=1582678800000&endTime=1582682400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8738 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582682400000&endTime=1582686000000 symbol=ETHUSDT&startTime=1582682400000&endTime=1582686000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8739 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582686000000&endTime=1582689600000 symbol=ETHUSDT&startTime=1582686000000&endTime=1582689600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8740 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582689600000&endTime=1582693200000 symbol=ETHUSDT&startTime=1582689600000&endTime=1582693200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8741 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582693200000&endTime=1582696800000 symbol=ETHUSDT&startTime=1582693200000&endTime=1582696800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8742 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582696800000&endTime=1582700400000 symbol=ETHUSDT&startTime=1582696800000&endTime=1582700400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8743 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582700400000&endTime=1582704000000 symbol=ETHUSDT&startTime=1582700400000&endTime=1582704000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8744 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582704000000&endTime=1582707600000 symbol=ETHUSDT&startTime=1582704000000&endTime=1582707600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8745 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582707600000&endTime=1582711200000 symbol=ETHUSDT&startTime=1582707600000&endTime=1582711200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8746 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582711200000&endTime=1582714800000 symbol=ETHUSDT&startTime=1582711200000&endTime=1582714800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8747 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582714800000&endTime=1582718400000 symbol=ETHUSDT&startTime=1582714800000&endTime=1582718400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8748 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582718400000&endTime=1582722000000 symbol=ETHUSDT&startTime=1582718400000&endTime=1582722000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8749 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582722000000&endTime=1582725600000 symbol=ETHUSDT&startTime=1582722000000&endTime=1582725600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8750 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582725600000&endTime=1582729200000 symbol=ETHUSDT&startTime=1582725600000&endTime=1582729200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8751 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582729200000&endTime=1582732800000 symbol=ETHUSDT&startTime=1582729200000&endTime=1582732800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8752 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582732800000&endTime=1582736400000 symbol=ETHUSDT&startTime=1582732800000&endTime=1582736400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8753 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582736400000&endTime=1582740000000 symbol=ETHUSDT&startTime=1582736400000&endTime=1582740000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8754 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582740000000&endTime=1582743600000 symbol=ETHUSDT&startTime=1582740000000&endTime=1582743600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8755 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582743600000&endTime=1582747200000 symbol=ETHUSDT&startTime=1582743600000&endTime=1582747200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8756 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582747200000&endTime=1582750800000 symbol=ETHUSDT&startTime=1582747200000&endTime=1582750800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8757 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582750800000&endTime=1582754400000 symbol=ETHUSDT&startTime=1582750800000&endTime=1582754400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8758 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582754400000&endTime=1582758000000 symbol=ETHUSDT&startTime=1582754400000&endTime=1582758000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8759 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=ETHUSDT&startTime=1582758000000&endTime=1582761600000 symbol=ETHUSDT&startTime=1582758000000&endTime=1582761600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8760 /8760
