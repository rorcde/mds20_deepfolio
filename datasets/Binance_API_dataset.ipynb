# %%
from google.colab import drive
import numpy as np
import pandas as pd
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# Imports and classes from https://bablofil.ru/binance-api/

import time
import json
import urllib
import hmac, hashlib
import requests

from urllib.parse import urlparse, urlencode
from urllib.request import Request, urlopen

class Binance():

    methods = {
            # public methods
            'ping':             {'url':'api/v1/ping', 'method': 'GET', 'private': False},
            'time':             {'url':'api/v1/time', 'method': 'GET', 'private': False},
            'exchangeInfo':     {'url':'api/v1/exchangeInfo', 'method': 'GET', 'private': False},
            'depth':            {'url': 'api/v1/depth', 'method': 'GET', 'private': False},
            'trades':           {'url': 'api/v1/trades', 'method': 'GET', 'private': False},
            'historicalTrades': {'url': 'api/v1/historicalTrades', 'method': 'GET', 'private': False},
            'aggTrades':        {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False},
            'klines':           {'url': 'api/v1/klines', 'method': 'GET', 'private': False},
            'ticker24hr':       {'url': 'api/v1/ticker/24hr', 'method': 'GET', 'private': False},
            'tickerPrice':      {'url': 'api/v3/ticker/price', 'method': 'GET', 'private': False},
            'tickerBookTicker': {'url': 'api/v3/ticker/bookTicker', 'method': 'GET', 'private': False},
            # private methods
            'createOrder':      {'url': 'api/v3/order', 'method': 'POST', 'private': True},
            'testOrder':        {'url': 'api/v3/order/test', 'method': 'POST', 'private': True},
            'orderInfo':        {'url': 'api/v3/order', 'method': 'GET', 'private': True},
            'cancelOrder':      {'url': 'api/v3/order', 'method': 'DELETE', 'private': True},
            'openOrders':       {'url': 'api/v3/openOrders', 'method': 'GET', 'private': True},
            'allOrders':        {'url': 'api/v3/allOrders', 'method': 'GET', 'private': True},
            'account':          {'url': 'api/v3/account', 'method': 'GET', 'private': True},
            'myTrades':         {'url': 'api/v3/myTrades', 'method': 'GET', 'private': True},
            # wapi
            'depositAddress':   {'url': 'wapi/v3/depositAddress.html', 'method':'GET', 'private':True},
            'withdraw':   {'url': 'wapi/v3/withdraw.html', 'method':'POST', 'private':True},
            'depositHistory': {'url': 'wapi/v3/depositHistory.html', 'method':'GET', 'private':True},
            'withdrawHistory': {'url': 'wapi/v3/withdrawHistory.html', 'method':'GET', 'private':True},
            'assetDetail': {'url': 'wapi/v3/assetDetail.html', 'method':'GET', 'private':True},
            'tradeFee': {'url': 'wapi/v3/tradeFee.html', 'method':'GET', 'private':True},
            'accountStatus': {'url': 'wapi/v3/accountStatus.html', 'method':'GET', 'private':True},
            'systemStatus': {'url': 'wapi/v3/systemStatus.html', 'method':'GET', 'private':True},
            'assetDust': {'url': 'sapi/v1/asset/dust', 'method':'POST', 'private':True},
            'dustLog': {'url': 'wapi/v3/userAssetDribbletLog.html', 'method':'GET', 'private':True},
            'assetAssetDividend': {'url': 'sapi/v1/asset/assetDividend', 'method':'GET', 'private':True},
            #sapi
            'marginTransfer': {'url': 'sapi/v1/margin/transfer', 'method': 'POST', 'private':True},
            'marginLoan': {'url': 'sapi/v1/margin/loan', 'method': 'POST', 'private':True},
            'marginRepay': {'url': 'sapi/v1/margin/repay', 'method': 'POST', 'private':True},
            'marginCreateOrder': {'url': 'sapi/v1/margin/order', 'method': 'POST', 'private':True},
            'marginCancelOrder': {'url': 'sapi/v1/margin/order', 'method': 'DELETE', 'private':True},
            'marginOrderInfo': {'url': 'sapi/v1/margin/order', 'method': 'GET', 'private':True},
            'marginAccount': {'url': 'sapi/v1/margin/account', 'method': 'POST', 'private':True},
            'marginOpenOrders': {'url': 'sapi/v1/margin/openOrders', 'method': 'GET', 'private':True},
            'marginAllOrders': {'url': 'sapi/v1/margin/allOrders', 'method': 'GET', 'private':True},
            'marginAsset': {'url': 'sapi/v1/margin/asset', 'method': 'POST', 'private':True},
            'marginPair': {'url': 'sapi/v1/margin/pair', 'method': 'POST', 'private':True},
            'marginPriceIndex': {'url': 'sapi/v1/margin/priceIndex', 'method': 'POST', 'private':True},
            'marginMyTrades': {'url': 'sapi/v1/margin/myTrades', 'method': 'GET', 'private':True},
            'marginMaxBorrowable': {'url': 'sapi/v1/margin/maxBorrowable', 'method': 'GET', 'private':True},
            'marginmaxTransferable': {'url': 'sapi/v1/margin/maxTransferable', 'method': 'GET', 'private':True},            
   }
    
    def __init__(self, API_KEY, API_SECRET):
        self.API_KEY = API_KEY
        self.API_SECRET = bytearray(API_SECRET, encoding='utf-8')
        self.shift_seconds = 0

    def __getattr__(self, name):
        def wrapper(*args, **kwargs):
            kwargs.update(command=name)
            return self.call_api(**kwargs)
        return wrapper

    def set_shift_seconds(self, seconds):
        self.shift_seconds = seconds
        
    def call_api(self, **kwargs):

        command = kwargs.pop('command')
        api_url = 'https://api.binance.com/' + self.methods[command]['url']

        payload = kwargs
        headers = {}
        
        payload_str = urllib.parse.urlencode(payload)
        if self.methods[command]['private']:
            payload.update({'timestamp': int(time.time() + self.shift_seconds - 1) * 1000})
            payload_str = urllib.parse.urlencode(payload).encode('utf-8')
            sign = hmac.new(
                key=self.API_SECRET,
                msg=payload_str,
                digestmod=hashlib.sha256
            ).hexdigest()

            payload_str = payload_str.decode("utf-8") + "&signature="+str(sign) 
            headers = {"X-MBX-APIKEY": self.API_KEY}

        if self.methods[command]['method'] == 'GET' or self.methods[command]['url'].startswith('sapi'):
            api_url += '?' + payload_str

        print(api_url, payload_str, self.methods[command])
        response = requests.request(method=self.methods[command]['method'], url=api_url, data="" if self.methods[command]['method'] == 'GET' else payload_str, headers=headers)

            
        if 'code' in response.text:
            print(response.text)
        return response.json()

# %%
# Bot for downloading the history
bot = Binance(
    API_KEY='D7...Ejj',
    API_SECRET='gwQ...u3A'
)

# %%
# Setting the starting point of dataset
start = 1546300800000 # 01.01.2019
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
for month, n_days in zip(range(8,12), days_in_month[8:]):
  day_start = sum(days_in_month[:month])
  day_end = day_start + n_days
  # Root where to save files
  title = r"/content/drive/MyDrive/Sequential_datasets_2/EOS/"+str(month)+".csv"
  history = []
  for hour in range(24*day_start + 1, 24*day_end + 1):
    # Symbol - the pair of currencies, difference between start and end - no more than 1 hour
    history += [bot.aggTrades(symbol='EOSUSDT', startTime = start+(hour-1)*60000*60, endTime = start+hour*60000*60)]
    print(hour,'/8760')
  history_list = []
  for i in history:
    for j in i:
      # Setting the column names
      history_list += [[j['M'],j['T'],j['a'],j['f'], j['l'], j['m'], j['p'], j['q']]]
  data = pd.DataFrame(history_list, columns= ['M', 'T', 'a', 'f', 'l', 'm', 'p', 'q'])
  data.to_csv(title)
# Out:
# Streaming output truncated to the last 5000 lines.
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568836800000&endTime=1568840400000 symbol=EOSUSDT&startTime=1568836800000&endTime=1568840400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6261 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568840400000&endTime=1568844000000 symbol=EOSUSDT&startTime=1568840400000&endTime=1568844000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6262 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568844000000&endTime=1568847600000 symbol=EOSUSDT&startTime=1568844000000&endTime=1568847600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6263 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568847600000&endTime=1568851200000 symbol=EOSUSDT&startTime=1568847600000&endTime=1568851200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6264 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568851200000&endTime=1568854800000 symbol=EOSUSDT&startTime=1568851200000&endTime=1568854800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6265 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568854800000&endTime=1568858400000 symbol=EOSUSDT&startTime=1568854800000&endTime=1568858400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6266 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568858400000&endTime=1568862000000 symbol=EOSUSDT&startTime=1568858400000&endTime=1568862000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6267 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568862000000&endTime=1568865600000 symbol=EOSUSDT&startTime=1568862000000&endTime=1568865600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6268 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568865600000&endTime=1568869200000 symbol=EOSUSDT&startTime=1568865600000&endTime=1568869200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6269 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568869200000&endTime=1568872800000 symbol=EOSUSDT&startTime=1568869200000&endTime=1568872800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6270 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568872800000&endTime=1568876400000 symbol=EOSUSDT&startTime=1568872800000&endTime=1568876400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6271 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568876400000&endTime=1568880000000 symbol=EOSUSDT&startTime=1568876400000&endTime=1568880000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6272 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568880000000&endTime=1568883600000 symbol=EOSUSDT&startTime=1568880000000&endTime=1568883600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6273 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568883600000&endTime=1568887200000 symbol=EOSUSDT&startTime=1568883600000&endTime=1568887200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6274 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568887200000&endTime=1568890800000 symbol=EOSUSDT&startTime=1568887200000&endTime=1568890800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6275 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568890800000&endTime=1568894400000 symbol=EOSUSDT&startTime=1568890800000&endTime=1568894400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6276 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568894400000&endTime=1568898000000 symbol=EOSUSDT&startTime=1568894400000&endTime=1568898000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6277 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568898000000&endTime=1568901600000 symbol=EOSUSDT&startTime=1568898000000&endTime=1568901600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6278 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568901600000&endTime=1568905200000 symbol=EOSUSDT&startTime=1568901600000&endTime=1568905200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6279 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568905200000&endTime=1568908800000 symbol=EOSUSDT&startTime=1568905200000&endTime=1568908800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6280 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568908800000&endTime=1568912400000 symbol=EOSUSDT&startTime=1568908800000&endTime=1568912400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6281 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568912400000&endTime=1568916000000 symbol=EOSUSDT&startTime=1568912400000&endTime=1568916000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6282 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568916000000&endTime=1568919600000 symbol=EOSUSDT&startTime=1568916000000&endTime=1568919600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6283 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568919600000&endTime=1568923200000 symbol=EOSUSDT&startTime=1568919600000&endTime=1568923200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6284 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568923200000&endTime=1568926800000 symbol=EOSUSDT&startTime=1568923200000&endTime=1568926800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6285 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568926800000&endTime=1568930400000 symbol=EOSUSDT&startTime=1568926800000&endTime=1568930400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6286 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568930400000&endTime=1568934000000 symbol=EOSUSDT&startTime=1568930400000&endTime=1568934000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6287 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568934000000&endTime=1568937600000 symbol=EOSUSDT&startTime=1568934000000&endTime=1568937600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6288 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568937600000&endTime=1568941200000 symbol=EOSUSDT&startTime=1568937600000&endTime=1568941200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6289 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568941200000&endTime=1568944800000 symbol=EOSUSDT&startTime=1568941200000&endTime=1568944800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6290 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568944800000&endTime=1568948400000 symbol=EOSUSDT&startTime=1568944800000&endTime=1568948400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6291 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568948400000&endTime=1568952000000 symbol=EOSUSDT&startTime=1568948400000&endTime=1568952000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6292 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568952000000&endTime=1568955600000 symbol=EOSUSDT&startTime=1568952000000&endTime=1568955600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6293 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568955600000&endTime=1568959200000 symbol=EOSUSDT&startTime=1568955600000&endTime=1568959200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6294 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568959200000&endTime=1568962800000 symbol=EOSUSDT&startTime=1568959200000&endTime=1568962800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6295 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568962800000&endTime=1568966400000 symbol=EOSUSDT&startTime=1568962800000&endTime=1568966400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6296 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568966400000&endTime=1568970000000 symbol=EOSUSDT&startTime=1568966400000&endTime=1568970000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6297 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568970000000&endTime=1568973600000 symbol=EOSUSDT&startTime=1568970000000&endTime=1568973600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6298 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568973600000&endTime=1568977200000 symbol=EOSUSDT&startTime=1568973600000&endTime=1568977200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6299 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568977200000&endTime=1568980800000 symbol=EOSUSDT&startTime=1568977200000&endTime=1568980800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6300 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568980800000&endTime=1568984400000 symbol=EOSUSDT&startTime=1568980800000&endTime=1568984400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6301 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568984400000&endTime=1568988000000 symbol=EOSUSDT&startTime=1568984400000&endTime=1568988000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6302 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568988000000&endTime=1568991600000 symbol=EOSUSDT&startTime=1568988000000&endTime=1568991600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6303 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568991600000&endTime=1568995200000 symbol=EOSUSDT&startTime=1568991600000&endTime=1568995200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6304 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568995200000&endTime=1568998800000 symbol=EOSUSDT&startTime=1568995200000&endTime=1568998800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6305 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1568998800000&endTime=1569002400000 symbol=EOSUSDT&startTime=1568998800000&endTime=1569002400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6306 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569002400000&endTime=1569006000000 symbol=EOSUSDT&startTime=1569002400000&endTime=1569006000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6307 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569006000000&endTime=1569009600000 symbol=EOSUSDT&startTime=1569006000000&endTime=1569009600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6308 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569009600000&endTime=1569013200000 symbol=EOSUSDT&startTime=1569009600000&endTime=1569013200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6309 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569013200000&endTime=1569016800000 symbol=EOSUSDT&startTime=1569013200000&endTime=1569016800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6310 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569016800000&endTime=1569020400000 symbol=EOSUSDT&startTime=1569016800000&endTime=1569020400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6311 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569020400000&endTime=1569024000000 symbol=EOSUSDT&startTime=1569020400000&endTime=1569024000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6312 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569024000000&endTime=1569027600000 symbol=EOSUSDT&startTime=1569024000000&endTime=1569027600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6313 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569027600000&endTime=1569031200000 symbol=EOSUSDT&startTime=1569027600000&endTime=1569031200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6314 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569031200000&endTime=1569034800000 symbol=EOSUSDT&startTime=1569031200000&endTime=1569034800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6315 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569034800000&endTime=1569038400000 symbol=EOSUSDT&startTime=1569034800000&endTime=1569038400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6316 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569038400000&endTime=1569042000000 symbol=EOSUSDT&startTime=1569038400000&endTime=1569042000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6317 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569042000000&endTime=1569045600000 symbol=EOSUSDT&startTime=1569042000000&endTime=1569045600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6318 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569045600000&endTime=1569049200000 symbol=EOSUSDT&startTime=1569045600000&endTime=1569049200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6319 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569049200000&endTime=1569052800000 symbol=EOSUSDT&startTime=1569049200000&endTime=1569052800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6320 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569052800000&endTime=1569056400000 symbol=EOSUSDT&startTime=1569052800000&endTime=1569056400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6321 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569056400000&endTime=1569060000000 symbol=EOSUSDT&startTime=1569056400000&endTime=1569060000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6322 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569060000000&endTime=1569063600000 symbol=EOSUSDT&startTime=1569060000000&endTime=1569063600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6323 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569063600000&endTime=1569067200000 symbol=EOSUSDT&startTime=1569063600000&endTime=1569067200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6324 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569067200000&endTime=1569070800000 symbol=EOSUSDT&startTime=1569067200000&endTime=1569070800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6325 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569070800000&endTime=1569074400000 symbol=EOSUSDT&startTime=1569070800000&endTime=1569074400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6326 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569074400000&endTime=1569078000000 symbol=EOSUSDT&startTime=1569074400000&endTime=1569078000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6327 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569078000000&endTime=1569081600000 symbol=EOSUSDT&startTime=1569078000000&endTime=1569081600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6328 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569081600000&endTime=1569085200000 symbol=EOSUSDT&startTime=1569081600000&endTime=1569085200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6329 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569085200000&endTime=1569088800000 symbol=EOSUSDT&startTime=1569085200000&endTime=1569088800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6330 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569088800000&endTime=1569092400000 symbol=EOSUSDT&startTime=1569088800000&endTime=1569092400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6331 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569092400000&endTime=1569096000000 symbol=EOSUSDT&startTime=1569092400000&endTime=1569096000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6332 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569096000000&endTime=1569099600000 symbol=EOSUSDT&startTime=1569096000000&endTime=1569099600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6333 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569099600000&endTime=1569103200000 symbol=EOSUSDT&startTime=1569099600000&endTime=1569103200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6334 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569103200000&endTime=1569106800000 symbol=EOSUSDT&startTime=1569103200000&endTime=1569106800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6335 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569106800000&endTime=1569110400000 symbol=EOSUSDT&startTime=1569106800000&endTime=1569110400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6336 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569110400000&endTime=1569114000000 symbol=EOSUSDT&startTime=1569110400000&endTime=1569114000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6337 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569114000000&endTime=1569117600000 symbol=EOSUSDT&startTime=1569114000000&endTime=1569117600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6338 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569117600000&endTime=1569121200000 symbol=EOSUSDT&startTime=1569117600000&endTime=1569121200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6339 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569121200000&endTime=1569124800000 symbol=EOSUSDT&startTime=1569121200000&endTime=1569124800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6340 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569124800000&endTime=1569128400000 symbol=EOSUSDT&startTime=1569124800000&endTime=1569128400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6341 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569128400000&endTime=1569132000000 symbol=EOSUSDT&startTime=1569128400000&endTime=1569132000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6342 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569132000000&endTime=1569135600000 symbol=EOSUSDT&startTime=1569132000000&endTime=1569135600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6343 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569135600000&endTime=1569139200000 symbol=EOSUSDT&startTime=1569135600000&endTime=1569139200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6344 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569139200000&endTime=1569142800000 symbol=EOSUSDT&startTime=1569139200000&endTime=1569142800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6345 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569142800000&endTime=1569146400000 symbol=EOSUSDT&startTime=1569142800000&endTime=1569146400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6346 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569146400000&endTime=1569150000000 symbol=EOSUSDT&startTime=1569146400000&endTime=1569150000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6347 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569150000000&endTime=1569153600000 symbol=EOSUSDT&startTime=1569150000000&endTime=1569153600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6348 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569153600000&endTime=1569157200000 symbol=EOSUSDT&startTime=1569153600000&endTime=1569157200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6349 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569157200000&endTime=1569160800000 symbol=EOSUSDT&startTime=1569157200000&endTime=1569160800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6350 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569160800000&endTime=1569164400000 symbol=EOSUSDT&startTime=1569160800000&endTime=1569164400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6351 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569164400000&endTime=1569168000000 symbol=EOSUSDT&startTime=1569164400000&endTime=1569168000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6352 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569168000000&endTime=1569171600000 symbol=EOSUSDT&startTime=1569168000000&endTime=1569171600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6353 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569171600000&endTime=1569175200000 symbol=EOSUSDT&startTime=1569171600000&endTime=1569175200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6354 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569175200000&endTime=1569178800000 symbol=EOSUSDT&startTime=1569175200000&endTime=1569178800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6355 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569178800000&endTime=1569182400000 symbol=EOSUSDT&startTime=1569178800000&endTime=1569182400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6356 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569182400000&endTime=1569186000000 symbol=EOSUSDT&startTime=1569182400000&endTime=1569186000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6357 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569186000000&endTime=1569189600000 symbol=EOSUSDT&startTime=1569186000000&endTime=1569189600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6358 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569189600000&endTime=1569193200000 symbol=EOSUSDT&startTime=1569189600000&endTime=1569193200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6359 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569193200000&endTime=1569196800000 symbol=EOSUSDT&startTime=1569193200000&endTime=1569196800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6360 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569196800000&endTime=1569200400000 symbol=EOSUSDT&startTime=1569196800000&endTime=1569200400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6361 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569200400000&endTime=1569204000000 symbol=EOSUSDT&startTime=1569200400000&endTime=1569204000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6362 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569204000000&endTime=1569207600000 symbol=EOSUSDT&startTime=1569204000000&endTime=1569207600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6363 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569207600000&endTime=1569211200000 symbol=EOSUSDT&startTime=1569207600000&endTime=1569211200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6364 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569211200000&endTime=1569214800000 symbol=EOSUSDT&startTime=1569211200000&endTime=1569214800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6365 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569214800000&endTime=1569218400000 symbol=EOSUSDT&startTime=1569214800000&endTime=1569218400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6366 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569218400000&endTime=1569222000000 symbol=EOSUSDT&startTime=1569218400000&endTime=1569222000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6367 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569222000000&endTime=1569225600000 symbol=EOSUSDT&startTime=1569222000000&endTime=1569225600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6368 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569225600000&endTime=1569229200000 symbol=EOSUSDT&startTime=1569225600000&endTime=1569229200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6369 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569229200000&endTime=1569232800000 symbol=EOSUSDT&startTime=1569229200000&endTime=1569232800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6370 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569232800000&endTime=1569236400000 symbol=EOSUSDT&startTime=1569232800000&endTime=1569236400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6371 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569236400000&endTime=1569240000000 symbol=EOSUSDT&startTime=1569236400000&endTime=1569240000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6372 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569240000000&endTime=1569243600000 symbol=EOSUSDT&startTime=1569240000000&endTime=1569243600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6373 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569243600000&endTime=1569247200000 symbol=EOSUSDT&startTime=1569243600000&endTime=1569247200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6374 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569247200000&endTime=1569250800000 symbol=EOSUSDT&startTime=1569247200000&endTime=1569250800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6375 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569250800000&endTime=1569254400000 symbol=EOSUSDT&startTime=1569250800000&endTime=1569254400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6376 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569254400000&endTime=1569258000000 symbol=EOSUSDT&startTime=1569254400000&endTime=1569258000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6377 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569258000000&endTime=1569261600000 symbol=EOSUSDT&startTime=1569258000000&endTime=1569261600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6378 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569261600000&endTime=1569265200000 symbol=EOSUSDT&startTime=1569261600000&endTime=1569265200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6379 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569265200000&endTime=1569268800000 symbol=EOSUSDT&startTime=1569265200000&endTime=1569268800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6380 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569268800000&endTime=1569272400000 symbol=EOSUSDT&startTime=1569268800000&endTime=1569272400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6381 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569272400000&endTime=1569276000000 symbol=EOSUSDT&startTime=1569272400000&endTime=1569276000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6382 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569276000000&endTime=1569279600000 symbol=EOSUSDT&startTime=1569276000000&endTime=1569279600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6383 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569279600000&endTime=1569283200000 symbol=EOSUSDT&startTime=1569279600000&endTime=1569283200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6384 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569283200000&endTime=1569286800000 symbol=EOSUSDT&startTime=1569283200000&endTime=1569286800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6385 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569286800000&endTime=1569290400000 symbol=EOSUSDT&startTime=1569286800000&endTime=1569290400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6386 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569290400000&endTime=1569294000000 symbol=EOSUSDT&startTime=1569290400000&endTime=1569294000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6387 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569294000000&endTime=1569297600000 symbol=EOSUSDT&startTime=1569294000000&endTime=1569297600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6388 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569297600000&endTime=1569301200000 symbol=EOSUSDT&startTime=1569297600000&endTime=1569301200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6389 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569301200000&endTime=1569304800000 symbol=EOSUSDT&startTime=1569301200000&endTime=1569304800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6390 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569304800000&endTime=1569308400000 symbol=EOSUSDT&startTime=1569304800000&endTime=1569308400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6391 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569308400000&endTime=1569312000000 symbol=EOSUSDT&startTime=1569308400000&endTime=1569312000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6392 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569312000000&endTime=1569315600000 symbol=EOSUSDT&startTime=1569312000000&endTime=1569315600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6393 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569315600000&endTime=1569319200000 symbol=EOSUSDT&startTime=1569315600000&endTime=1569319200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6394 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569319200000&endTime=1569322800000 symbol=EOSUSDT&startTime=1569319200000&endTime=1569322800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6395 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569322800000&endTime=1569326400000 symbol=EOSUSDT&startTime=1569322800000&endTime=1569326400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6396 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569326400000&endTime=1569330000000 symbol=EOSUSDT&startTime=1569326400000&endTime=1569330000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6397 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569330000000&endTime=1569333600000 symbol=EOSUSDT&startTime=1569330000000&endTime=1569333600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6398 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569333600000&endTime=1569337200000 symbol=EOSUSDT&startTime=1569333600000&endTime=1569337200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6399 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569337200000&endTime=1569340800000 symbol=EOSUSDT&startTime=1569337200000&endTime=1569340800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6400 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569340800000&endTime=1569344400000 symbol=EOSUSDT&startTime=1569340800000&endTime=1569344400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6401 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569344400000&endTime=1569348000000 symbol=EOSUSDT&startTime=1569344400000&endTime=1569348000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6402 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569348000000&endTime=1569351600000 symbol=EOSUSDT&startTime=1569348000000&endTime=1569351600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6403 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569351600000&endTime=1569355200000 symbol=EOSUSDT&startTime=1569351600000&endTime=1569355200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6404 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569355200000&endTime=1569358800000 symbol=EOSUSDT&startTime=1569355200000&endTime=1569358800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6405 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569358800000&endTime=1569362400000 symbol=EOSUSDT&startTime=1569358800000&endTime=1569362400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6406 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569362400000&endTime=1569366000000 symbol=EOSUSDT&startTime=1569362400000&endTime=1569366000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6407 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569366000000&endTime=1569369600000 symbol=EOSUSDT&startTime=1569366000000&endTime=1569369600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6408 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569369600000&endTime=1569373200000 symbol=EOSUSDT&startTime=1569369600000&endTime=1569373200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6409 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569373200000&endTime=1569376800000 symbol=EOSUSDT&startTime=1569373200000&endTime=1569376800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6410 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569376800000&endTime=1569380400000 symbol=EOSUSDT&startTime=1569376800000&endTime=1569380400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6411 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569380400000&endTime=1569384000000 symbol=EOSUSDT&startTime=1569380400000&endTime=1569384000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6412 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569384000000&endTime=1569387600000 symbol=EOSUSDT&startTime=1569384000000&endTime=1569387600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6413 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569387600000&endTime=1569391200000 symbol=EOSUSDT&startTime=1569387600000&endTime=1569391200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6414 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569391200000&endTime=1569394800000 symbol=EOSUSDT&startTime=1569391200000&endTime=1569394800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6415 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569394800000&endTime=1569398400000 symbol=EOSUSDT&startTime=1569394800000&endTime=1569398400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6416 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569398400000&endTime=1569402000000 symbol=EOSUSDT&startTime=1569398400000&endTime=1569402000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6417 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569402000000&endTime=1569405600000 symbol=EOSUSDT&startTime=1569402000000&endTime=1569405600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6418 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569405600000&endTime=1569409200000 symbol=EOSUSDT&startTime=1569405600000&endTime=1569409200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6419 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569409200000&endTime=1569412800000 symbol=EOSUSDT&startTime=1569409200000&endTime=1569412800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6420 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569412800000&endTime=1569416400000 symbol=EOSUSDT&startTime=1569412800000&endTime=1569416400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6421 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569416400000&endTime=1569420000000 symbol=EOSUSDT&startTime=1569416400000&endTime=1569420000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6422 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569420000000&endTime=1569423600000 symbol=EOSUSDT&startTime=1569420000000&endTime=1569423600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6423 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569423600000&endTime=1569427200000 symbol=EOSUSDT&startTime=1569423600000&endTime=1569427200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6424 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569427200000&endTime=1569430800000 symbol=EOSUSDT&startTime=1569427200000&endTime=1569430800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6425 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569430800000&endTime=1569434400000 symbol=EOSUSDT&startTime=1569430800000&endTime=1569434400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6426 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569434400000&endTime=1569438000000 symbol=EOSUSDT&startTime=1569434400000&endTime=1569438000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6427 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569438000000&endTime=1569441600000 symbol=EOSUSDT&startTime=1569438000000&endTime=1569441600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6428 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569441600000&endTime=1569445200000 symbol=EOSUSDT&startTime=1569441600000&endTime=1569445200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6429 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569445200000&endTime=1569448800000 symbol=EOSUSDT&startTime=1569445200000&endTime=1569448800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6430 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569448800000&endTime=1569452400000 symbol=EOSUSDT&startTime=1569448800000&endTime=1569452400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6431 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569452400000&endTime=1569456000000 symbol=EOSUSDT&startTime=1569452400000&endTime=1569456000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6432 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569456000000&endTime=1569459600000 symbol=EOSUSDT&startTime=1569456000000&endTime=1569459600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6433 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569459600000&endTime=1569463200000 symbol=EOSUSDT&startTime=1569459600000&endTime=1569463200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6434 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569463200000&endTime=1569466800000 symbol=EOSUSDT&startTime=1569463200000&endTime=1569466800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6435 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569466800000&endTime=1569470400000 symbol=EOSUSDT&startTime=1569466800000&endTime=1569470400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6436 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569470400000&endTime=1569474000000 symbol=EOSUSDT&startTime=1569470400000&endTime=1569474000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6437 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569474000000&endTime=1569477600000 symbol=EOSUSDT&startTime=1569474000000&endTime=1569477600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6438 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569477600000&endTime=1569481200000 symbol=EOSUSDT&startTime=1569477600000&endTime=1569481200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6439 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569481200000&endTime=1569484800000 symbol=EOSUSDT&startTime=1569481200000&endTime=1569484800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6440 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569484800000&endTime=1569488400000 symbol=EOSUSDT&startTime=1569484800000&endTime=1569488400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6441 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569488400000&endTime=1569492000000 symbol=EOSUSDT&startTime=1569488400000&endTime=1569492000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6442 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569492000000&endTime=1569495600000 symbol=EOSUSDT&startTime=1569492000000&endTime=1569495600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6443 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569495600000&endTime=1569499200000 symbol=EOSUSDT&startTime=1569495600000&endTime=1569499200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6444 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569499200000&endTime=1569502800000 symbol=EOSUSDT&startTime=1569499200000&endTime=1569502800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6445 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569502800000&endTime=1569506400000 symbol=EOSUSDT&startTime=1569502800000&endTime=1569506400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6446 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569506400000&endTime=1569510000000 symbol=EOSUSDT&startTime=1569506400000&endTime=1569510000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6447 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569510000000&endTime=1569513600000 symbol=EOSUSDT&startTime=1569510000000&endTime=1569513600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6448 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569513600000&endTime=1569517200000 symbol=EOSUSDT&startTime=1569513600000&endTime=1569517200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6449 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569517200000&endTime=1569520800000 symbol=EOSUSDT&startTime=1569517200000&endTime=1569520800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6450 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569520800000&endTime=1569524400000 symbol=EOSUSDT&startTime=1569520800000&endTime=1569524400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6451 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569524400000&endTime=1569528000000 symbol=EOSUSDT&startTime=1569524400000&endTime=1569528000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6452 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569528000000&endTime=1569531600000 symbol=EOSUSDT&startTime=1569528000000&endTime=1569531600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6453 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569531600000&endTime=1569535200000 symbol=EOSUSDT&startTime=1569531600000&endTime=1569535200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6454 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569535200000&endTime=1569538800000 symbol=EOSUSDT&startTime=1569535200000&endTime=1569538800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6455 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569538800000&endTime=1569542400000 symbol=EOSUSDT&startTime=1569538800000&endTime=1569542400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6456 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569542400000&endTime=1569546000000 symbol=EOSUSDT&startTime=1569542400000&endTime=1569546000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6457 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569546000000&endTime=1569549600000 symbol=EOSUSDT&startTime=1569546000000&endTime=1569549600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6458 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569549600000&endTime=1569553200000 symbol=EOSUSDT&startTime=1569549600000&endTime=1569553200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6459 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569553200000&endTime=1569556800000 symbol=EOSUSDT&startTime=1569553200000&endTime=1569556800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6460 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569556800000&endTime=1569560400000 symbol=EOSUSDT&startTime=1569556800000&endTime=1569560400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6461 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1569560400000&endTime=1569564000000 symbol=EOSUSDT&startTime=1569560400000&endTime=1569564000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 6462 /8760
# ...
# 8693 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577595600000&endTime=1577599200000 symbol=EOSUSDT&startTime=1577595600000&endTime=1577599200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8694 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577599200000&endTime=1577602800000 symbol=EOSUSDT&startTime=1577599200000&endTime=1577602800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8695 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577602800000&endTime=1577606400000 symbol=EOSUSDT&startTime=1577602800000&endTime=1577606400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8696 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577606400000&endTime=1577610000000 symbol=EOSUSDT&startTime=1577606400000&endTime=1577610000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8697 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577610000000&endTime=1577613600000 symbol=EOSUSDT&startTime=1577610000000&endTime=1577613600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8698 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577613600000&endTime=1577617200000 symbol=EOSUSDT&startTime=1577613600000&endTime=1577617200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8699 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577617200000&endTime=1577620800000 symbol=EOSUSDT&startTime=1577617200000&endTime=1577620800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8700 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577620800000&endTime=1577624400000 symbol=EOSUSDT&startTime=1577620800000&endTime=1577624400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8701 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577624400000&endTime=1577628000000 symbol=EOSUSDT&startTime=1577624400000&endTime=1577628000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8702 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577628000000&endTime=1577631600000 symbol=EOSUSDT&startTime=1577628000000&endTime=1577631600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8703 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577631600000&endTime=1577635200000 symbol=EOSUSDT&startTime=1577631600000&endTime=1577635200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8704 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577635200000&endTime=1577638800000 symbol=EOSUSDT&startTime=1577635200000&endTime=1577638800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8705 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577638800000&endTime=1577642400000 symbol=EOSUSDT&startTime=1577638800000&endTime=1577642400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8706 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577642400000&endTime=1577646000000 symbol=EOSUSDT&startTime=1577642400000&endTime=1577646000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8707 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577646000000&endTime=1577649600000 symbol=EOSUSDT&startTime=1577646000000&endTime=1577649600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8708 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577649600000&endTime=1577653200000 symbol=EOSUSDT&startTime=1577649600000&endTime=1577653200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8709 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577653200000&endTime=1577656800000 symbol=EOSUSDT&startTime=1577653200000&endTime=1577656800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8710 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577656800000&endTime=1577660400000 symbol=EOSUSDT&startTime=1577656800000&endTime=1577660400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8711 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577660400000&endTime=1577664000000 symbol=EOSUSDT&startTime=1577660400000&endTime=1577664000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8712 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577664000000&endTime=1577667600000 symbol=EOSUSDT&startTime=1577664000000&endTime=1577667600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8713 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577667600000&endTime=1577671200000 symbol=EOSUSDT&startTime=1577667600000&endTime=1577671200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8714 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577671200000&endTime=1577674800000 symbol=EOSUSDT&startTime=1577671200000&endTime=1577674800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8715 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577674800000&endTime=1577678400000 symbol=EOSUSDT&startTime=1577674800000&endTime=1577678400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8716 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577678400000&endTime=1577682000000 symbol=EOSUSDT&startTime=1577678400000&endTime=1577682000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8717 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577682000000&endTime=1577685600000 symbol=EOSUSDT&startTime=1577682000000&endTime=1577685600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8718 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577685600000&endTime=1577689200000 symbol=EOSUSDT&startTime=1577685600000&endTime=1577689200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8719 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577689200000&endTime=1577692800000 symbol=EOSUSDT&startTime=1577689200000&endTime=1577692800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8720 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577692800000&endTime=1577696400000 symbol=EOSUSDT&startTime=1577692800000&endTime=1577696400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8721 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577696400000&endTime=1577700000000 symbol=EOSUSDT&startTime=1577696400000&endTime=1577700000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8722 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577700000000&endTime=1577703600000 symbol=EOSUSDT&startTime=1577700000000&endTime=1577703600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8723 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577703600000&endTime=1577707200000 symbol=EOSUSDT&startTime=1577703600000&endTime=1577707200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8724 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577707200000&endTime=1577710800000 symbol=EOSUSDT&startTime=1577707200000&endTime=1577710800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8725 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577710800000&endTime=1577714400000 symbol=EOSUSDT&startTime=1577710800000&endTime=1577714400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8726 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577714400000&endTime=1577718000000 symbol=EOSUSDT&startTime=1577714400000&endTime=1577718000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8727 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577718000000&endTime=1577721600000 symbol=EOSUSDT&startTime=1577718000000&endTime=1577721600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8728 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577721600000&endTime=1577725200000 symbol=EOSUSDT&startTime=1577721600000&endTime=1577725200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8729 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577725200000&endTime=1577728800000 symbol=EOSUSDT&startTime=1577725200000&endTime=1577728800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8730 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577728800000&endTime=1577732400000 symbol=EOSUSDT&startTime=1577728800000&endTime=1577732400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8731 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577732400000&endTime=1577736000000 symbol=EOSUSDT&startTime=1577732400000&endTime=1577736000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8732 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577736000000&endTime=1577739600000 symbol=EOSUSDT&startTime=1577736000000&endTime=1577739600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8733 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577739600000&endTime=1577743200000 symbol=EOSUSDT&startTime=1577739600000&endTime=1577743200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8734 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577743200000&endTime=1577746800000 symbol=EOSUSDT&startTime=1577743200000&endTime=1577746800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8735 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577746800000&endTime=1577750400000 symbol=EOSUSDT&startTime=1577746800000&endTime=1577750400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8736 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577750400000&endTime=1577754000000 symbol=EOSUSDT&startTime=1577750400000&endTime=1577754000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8737 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577754000000&endTime=1577757600000 symbol=EOSUSDT&startTime=1577754000000&endTime=1577757600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8738 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577757600000&endTime=1577761200000 symbol=EOSUSDT&startTime=1577757600000&endTime=1577761200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8739 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577761200000&endTime=1577764800000 symbol=EOSUSDT&startTime=1577761200000&endTime=1577764800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8740 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577764800000&endTime=1577768400000 symbol=EOSUSDT&startTime=1577764800000&endTime=1577768400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8741 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577768400000&endTime=1577772000000 symbol=EOSUSDT&startTime=1577768400000&endTime=1577772000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8742 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577772000000&endTime=1577775600000 symbol=EOSUSDT&startTime=1577772000000&endTime=1577775600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8743 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577775600000&endTime=1577779200000 symbol=EOSUSDT&startTime=1577775600000&endTime=1577779200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8744 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577779200000&endTime=1577782800000 symbol=EOSUSDT&startTime=1577779200000&endTime=1577782800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8745 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577782800000&endTime=1577786400000 symbol=EOSUSDT&startTime=1577782800000&endTime=1577786400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8746 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577786400000&endTime=1577790000000 symbol=EOSUSDT&startTime=1577786400000&endTime=1577790000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8747 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577790000000&endTime=1577793600000 symbol=EOSUSDT&startTime=1577790000000&endTime=1577793600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8748 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577793600000&endTime=1577797200000 symbol=EOSUSDT&startTime=1577793600000&endTime=1577797200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8749 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577797200000&endTime=1577800800000 symbol=EOSUSDT&startTime=1577797200000&endTime=1577800800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8750 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577800800000&endTime=1577804400000 symbol=EOSUSDT&startTime=1577800800000&endTime=1577804400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8751 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577804400000&endTime=1577808000000 symbol=EOSUSDT&startTime=1577804400000&endTime=1577808000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8752 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577808000000&endTime=1577811600000 symbol=EOSUSDT&startTime=1577808000000&endTime=1577811600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8753 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577811600000&endTime=1577815200000 symbol=EOSUSDT&startTime=1577811600000&endTime=1577815200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8754 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577815200000&endTime=1577818800000 symbol=EOSUSDT&startTime=1577815200000&endTime=1577818800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8755 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577818800000&endTime=1577822400000 symbol=EOSUSDT&startTime=1577818800000&endTime=1577822400000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8756 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577822400000&endTime=1577826000000 symbol=EOSUSDT&startTime=1577822400000&endTime=1577826000000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8757 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577826000000&endTime=1577829600000 symbol=EOSUSDT&startTime=1577826000000&endTime=1577829600000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8758 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577829600000&endTime=1577833200000 symbol=EOSUSDT&startTime=1577829600000&endTime=1577833200000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8759 /8760
# https://api.binance.com/api/v1/aggTrades?symbol=EOSUSDT&startTime=1577833200000&endTime=1577836800000 symbol=EOSUSDT&startTime=1577833200000&endTime=1577836800000 {'url': 'api/v1/aggTrades', 'method': 'GET', 'private': False}
# 8760 /8760

# %%
data['time'] = pd.to_datetime(data['T'], unit = 'ms')

# %%
data
# Out:
#         Unnamed: 0     M  ...        q                    time
# 0                0  True  ...  0.08708 2019-02-27 00:00:01.768
# 1                1  True  ...  0.07481 2019-02-27 00:00:04.087
# 2                2  True  ...  7.75500 2019-02-27 00:00:06.160
# 3                3  True  ...  7.39108 2019-02-27 00:00:06.160
# 4                4  True  ...  0.08639 2019-02-27 00:00:07.979
# ...            ...   ...  ...      ...                     ...
# 571985      571985  True  ...  0.08905 2019-03-03 23:59:51.392
# 571986      571986  True  ...  2.47696 2019-03-03 23:59:54.359
# 571987      571987  True  ...  2.00000 2019-03-03 23:59:55.698
# 571988      571988  True  ...  0.08901 2019-03-03 23:59:59.615
# 571989      571989  True  ...  2.15700 2019-03-03 23:59:59.820
#
# [571990 rows x 10 columns]
